# %% [markdown]
# Matheus Silva dos Santos - 22052573 <br>
# Felipe Fraxe Filho - 22251894

# %%
#Importação da Biblioteca ADBib
from ADBib import *

# %% [markdown]
# ## Distribuição de Frequências

# %% [markdown]
# Abaixo está um teste para a função de distribuição de frequências. A função `plot_histogram` recebe uma lista de valores 'data', onde será utilizada a função `build_histogram` para calcular a frequência de cada valor. A função `build_histogram` retorna um dicionário com os valores e suas respectivas frequências. A função `plot_histogram` então utiliza esses valores para plotar o histograma.
#
#
# Também é possível passar como parâmetro as strings para os eixos x e y do gráfico, e o título do gráfico. Se não passar nada, os valores padrões são 'Values' e 'Frequency', 'Histogram', respectivamente.

# %%
# Amostra de estudantes de uma turma de IPC
data = [59, 61, 74, 84, 86, 75, 96, 92, 53, 66,
        58, 49, 71, 72, 73, 66, 91, 68, 79, 79,
        64, 84, 86, 79, 88, 59, 98, 82, 69, 75,
        84, 61, 92, 84, 82, 62, 61, 88, 74, 58,
        60, 62, 75, 86, 88, 72, 90, 96, 51, 64]

plot_histogram(data)

# %% [markdown]
# **Conclusão (Supondo que os valores dessa amostra seja as notas dos estudantes de uma turma de IPC)**
#
#  A análise da distribuição de frequência das notas dos estudantes revela que a maioria das notas está concentrada na faixa de 60 a 90, com um pico de frequência nas nota 84. Isso sugere que muitos estudantes obtiveram notas altas. A variabilidade das notas é moderada, com uma leve tendência de assimetria positiva, indicando que as notas mais altas (acima de 90) são menos frequentes.

# %% [markdown]
# ## Medidas de Tendência Central

# %% [markdown]
# #### Média Aritmética

# %% [markdown]
# Abaixo está um teste da função `arithmetic_mean`. A função recebe uma lista de valores 'data' e retorna a média aritmética desses valores.

# %%
# Em uma amostra foram registradas a duração (em minutos) de 10 chamadas VoIP: 
data = [2.5, 3.5, 2.8, 1.9, 2.4, 2.6, 3.4, 2.8, 3.6, 2.5]
    
mean = arithmetic_mean(data)

print(f'Duração média de uma chamada VoIP: {mean} min')
plot_values_with_mean(data, mean)
# Out:
# Duração média de uma chamada VoIP: 2.8 min

# %% [markdown]
# **O que a média aritmética ajuda a identificar/revela?**
#
# A média aritmética é uma das medidas de tendência central mais simples e amplamente utilizadas. Ela ajuda a identificar o valor central de um conjunto de dados, revelando o valor típico ou "médio" das observações.
#
# **A média aritmética é indicada para quais tipos de amostra?**
#
# - **Distribuição Simétrica:** Quando os dados não são significativamente assimétricos e não possuem outliers extremos que possam distorcer o valor da média.
# - **Dados Numéricos:** Quando os dados são quantitativos e contínuos.
# - **Homogeneidade:** Quando os dados são relativamente homogêneos e não apresentam variações extremas.
#
# **Quando não usar a média aritmética?**
#
# - **Distribuição Assimétrica:** Se os dados são altamente assimétricos (possuem uma cauda longa à esquerda ou à direita), a média pode ser distorcida.
# - **Outliers:** Se existem outliers extremos, a média aritmética pode não representar bem a tendência central dos dados.
# - **Dados Categóricos:** Quando os dados são categóricos ou qualitativos, a média aritmética não é aplicável.
#
# **A amostra de exemplo é propícia para se utilizar a média aritmética?**
#
# Sim, pois os valores das durações das chamadas VoIP são dados quantitativos e contínuos. Além disso, os valores parecem estar distribuídos de forma relativamente homogênea e não há evidência de outliers extremos que possam distorcer significativamente a média.
#
# **Conclusão**
#
# A análise das durações das chamadas VoIP com base na média aritmética de 2,8 minutos sugere que, em média, as chamadas nesta amostra duraram aproximadamente 2,8 minutos. A média aritmética é uma medida adequada para esta amostra, pois os dados são quantitativos e relativamente homogêneos. No entanto, é importante lembrar que a média aritmética pode ser menos representativa em conjuntos de dados com distribuições altamente assimétricas ou com a presença de outliers extremos.

# %% [markdown]
# #### Média Ponderada

# %% [markdown]
# Abaixo está um teste da função `weighted_mean`. A função recebe uma lista de tuplas 'data' onde cada tupla é composta por um valor e seu respectivo peso. A função retorna a média ponderada desses valores.

# %%
# A amostra a seguir descreve (notas, créditos) de um estudante.
data = [(7, 4), (8, 2), (6, 2), (9, 2), (8, 4), (9, 4)]

mean = weighted_mean(data)

print(f'O coeficiente de rendimento do estudante é: {mean}')
plot_values_with_mean(data, mean)
# Out:
# O coeficiente de rendimento do estudante é: 7.89

# %% [markdown]
# **O que a média ponderada ajuda a identificar/revela?**
#
# A média ponderada é uma medida de tendência central que leva em conta a importância relativa de cada observação. Considerando a amostra de exemplo, isso significa que notas em disciplinas com mais créditos têm maior impacto na média do que notas em disciplinas com menos créditos. Portanto, a média ponderada revela uma avaliação mais justa e precisa do desempenho acadêmico do estudante, refletindo a carga horária ou a importância de cada curso.
#
# **A média ponderada é indicada para quais tipos de amostra?**
#
# - **Importância Relativa:** As observações têm diferentes níveis de importância ou peso.
# - **Dados Quantitativos:** Os dados são quantitativos e podem ser ponderados de acordo com os pesos atribuídos.
#
# **Quando não usar a média ponderada?**
#
# - **Pesos Desconhecidos ou Inconsistentes:** Se os pesos (ou importância relativa) não são conhecidos ou são inconsistentes.
# - **Dados Qualitativos:** Quando os dados são qualitativos e não podem ser ponderados de forma significativa.
# - **Uniformidade:** Quando todas as observações têm o mesmo nível de importância, nesse caso, a média aritmética simples pode ser utilizada.
#
# **Esta amostra é propícia para se utilizar a média ponderada?**
#
# Sim, a amostra fornecida é propícia para a utilização da média ponderada, pois as notas são associadas a diferentes créditos, o que indica a importância relativa de cada curso.
#
# **Conclusão**
#
# A análise das notas do estudante, ponderada pelos créditos das disciplinas, resultou em uma média ponderada de 7,89. Isso sugere que, levando em consideração a importância relativa de cada curso (créditos), o desempenho médio do estudante é de 7,89.

# %% [markdown]
# #### Média Geométrica

# %% [markdown]
# Abaxo está um teste da função `geometric_mean`. A função recebe uma lista de valores 'data' e retorna a média geométrica desses valores.

# %%
# Observou-se os seguintes valores de uma variável em um experimento:
data = [18, 13, 11, 8, 10, 58, 12]

mean = geometric_mean(data)

print(f'A média geométrica dos valores observados é: {mean}')
plot_values_with_mean(data, mean)
# Out:
# A média geométrica dos valores observados é: 14.63

# %% [markdown]
# **O que a média geométrica ajuda a identificar/revela?**
#
# - **Crescimento Proporcional:** É uma medida adequada para calcular a taxa de crescimento média de variáveis que crescem de forma proporcional.
# - **Mediana Multiplicativa:** Proporciona uma visão mais realista do valor central em conjuntos de dados com grande variabilidade ou outliers, especialmente quando os dados são distribuídos de forma multiplicativa.
# - **Redução de Impacto de Outliers:** Ao contrário da média aritmética, a média geométrica reduz o impacto de outliers grandes, pois considera o produto dos valores em vez da soma.
#
# **A média geométrica é indicada para quais tipos de amostra?**
#
# - **Crescimento Exponencial ou Multiplicativo:** Os dados refletem crescimentos ou decrescimentos exponenciais ou multiplicativos.
# - **Proporções e Taxas:** É comum em cálculos de médias de proporções, taxas de retorno, ou índices financeiros.
#
# **Quando não usar a média geométrica?**
#
# - **Valores Negativos ou Zeros:** A média geométrica não pode ser calculada com valores negativos ou zeros, pois envolve a raiz n-ésima do produto dos valores.
# - **Dados Aditivos:** Quando os dados são somados ou combinados de forma aditiva, a média aritmética é mais apropriada.
# - **Distribuição Simétrica Sem Crescimento Multiplicativo:** Para dados que são simétricos e não envolvem crescimento multiplicativo, a média aritmética pode ser mais adequada.
#
# **Esta amostra é propícia para se utilizar a média geométrica?**
#
# Sim, esta amostra pode ser propícia para a utilização da média geométrica, especialmente se os valores observados representam taxas de crescimento ou dados que variam de forma multiplicativa. A média geométrica fornece uma visão mais equilibrada do valor central, especialmente quando há uma alta variabilidade entre os valores, como pode ser visto com a presença do valor 58.
#
# **Conclusão**
#
# A análise dos valores observados no experimento, usando a média geométrica, resultou em um valor de 14,63. Este valor indica o valor central multiplicativo dos dados e representa uma taxa de crescimento média ao longo do experimento. A média geométrica é particularmente útil neste caso, pois proporciona uma visão mais equilibrada do valor central, especialmente devido a presença de um outlier, valor 58.

# %% [markdown]
# #### Média Harmônica

# %% [markdown]
# Abaixo está um teste da função `harmonic_mean`. A função recebe uma lista de valores 'data' e retorna a média harmônica desses valores.

# %%
# Considere o conjunto de medidas (em MFLOPS) obtidas em um experimento. 

data = [405, 367, 405, 419, 388]

mean = harmonic_mean(data)

print(f'O valor médio de MFLOPS é: {mean}')

plot_values_with_mean(data, mean)
# Out:
# O valor médio de MFLOPS é: 395.98

# %% [markdown]
# **O que a média harmônica ajuda a identificar/revela?**
#
# - **Média Ponderada Inversa:** É uma medida de tendência central que leva em consideração a média ponderada inversa dos valores.
# - **Média de Taxas ou Razões:** É ideal para calcular médias de taxas, como velocidades ou fluxos, onde as quantidades inversas são somadas.
# - **Impacto de Valores Baixos:** A média harmônica é mais sensível a valores baixos, o que a torna útil para evitar a subestimação de médias em conjuntos de dados com valores extremamente baixos.
#
# **A média harmônica é indicada para quais tipos de amostra?**
#
# - Representam taxas, razões ou velocidades (como MFLOPS, km/h, tarefas por hora).
# - Possuem valores estritamente positivos (não podem ser zero ou negativos).
# - Apresentam grande variabilidade, com valores extremos que podem distorcer outras médias.
#
# **Quando não usar a média harmônica?**
#
# - A amostra contém valores zero ou negativos, pois a fórmula envolve a divisão por cada valor.
# - O objetivo é calcular a média de valores que não representam taxas ou razões (como altura, peso, temperatura). Nesses casos, a média aritmética ou a mediana podem ser mais apropriadas.
#
# **Esta amostra é propícia para se utilizar a média harmônica?**
#
# Sim, a amostra de MFLOPS é propícia para o uso da média harmônica, pois:
#
# - Representa uma taxa de execução (operações por segundo).
# - Não contém valores zero ou negativos.
# - Pode apresentar variabilidade, com algumas medidas mais baixas impactando o desempenho geral.
#
# **Conclusão**
#
# A média harmônica de 395.98 MFLOPS indica a taxa média de execução do sistema, considerando a influência de cada medida individual. Essa medida é mais precisa e representativa do que a média aritmética para este tipo de amostra, pois leva em conta o impacto de valores mais baixos no desempenho geral. A utilização da média harmônica permite uma análise mais completa e acurada do desempenho do sistema em relação à taxa de execução de operações de ponto flutuante.

# %% [markdown]
# #### Média de Taxas (Caso 1)

# %% [markdown]
# **Caso 1:** Se a soma dos numeradores e a soma dos denominadores possuem um significado físico, a média da taxa é a taxa das médias.
#
# Abaixo está um teste da função `rate_mean_case1`. A função recebe uma lista de tuplas 'data' onde cada tupla é composta por um numerador e um denominador. A função retorna a média da taxa desses valores.

# %%
# Dado a amostra dos resultados das medições da taxa de perdas de trasmissão, onde o primeiro valor é a taxa de perda (em %) e o segundo valor é a duração da medição (em segundos) .

data = [(3.0, 100), (5.0, 100), (4.2, 100), (5.2, 100), (8.6, 200)]

mean = mean_rate_case1(data)

print(f'A taxa média de perda de transmissão é: {round(mean*100,2)} %')
print(f'\nA taxa média de perdas não é 5,2%, pois a janela de medição não é a mesma em todos os experimentos.')
# Out:
# A taxa média de perda de transmissão é: 4.33 %
#
# A taxa média de perdas não é 5,2%, pois a janela de medição não é a mesma em todos os experimentos.

# %% [markdown]
# #### Exercício (Slide 18 - Aula 2)

# %% [markdown]
# Um homem precisava fazer um reparo e comprou 80m de arame por R$ 40,00. Um tempo depois, ele precisou comprar mais 40m e pagou R$ 45,00. Posteriormente, comprou mais 12m por R$ 50,00. Quanto ele pagou, em média, por cada metro de arame?

# %%
#Resolução do exercício acima utilizando a média de taxas (Caso 1)
# Dados fornecidos no exercício
data = [(40, 80), (45, 40), (50, 12)]

mean = mean_rate_case1(data)

print(f'Custo médio por metro:  R$ {round(mean,2)}')
# Out:
# Custo médio por metro:  R$ 1.02

# %% [markdown]
# O exercício acima pode ser resolvido utilizando a média de taxas (caso 1). Estamos interessados em calcular o custo médio por unidade de arame, ou seja, quanto foi pago, em média, por cada metro de arame. Para isso, usamos o custo total (em reais) e a quantidade total de arame (em metros). Assim, o numerador seria o custo total e o denominador seria a quantidade total.
#
# **Conclusão**
#
# <pre>
# A média do custo por metro de arame, considerando todas as compras, é R$ 1,02 por metro. Isso indica que, em média, o homem pagou R$ 1,02 por cada metro de arame ao longo das três compras que fez.
# </pre>

# %% [markdown]
# #### Média de Taxas (Caso 2)

# %% [markdown]
# Caso 2: Se o denominador é uma constante e a soma do numerador tem um significado físico, a média aritmética das taxas pode ser utilizada.
#
# Abaixo está um teste da função `rate_mean_case2`. A função recebe uma lista de tuplas 'data' onde cada tupla é composta por um numerador e um denominador. A função retorna a média da taxa desses valores.

# %%
# Dado a amostra dos resultados das medições da taxa de perdas de trasmissão, onde o primeiro valor é a taxa de perda (em %) e o segundo valor é a duração da medição (em segundos) .

data = [(3.0, 100), (5.0, 100), (4.2, 100), (5.2, 100), (8.6, 100)]

mean = mean_rate_case2(data)

print(f'A taxa média de perda de transmissão é: {round(mean*100,2)} %')
# Out:
# A taxa média de perda de transmissão é: 5.2 %

# %% [markdown]
# #### Média de Taxas (Caso 3)

# %% [markdown]
# Caso 3: Se a soma dos denominadores tem um significado físico e os numeradores são constantes, então a média harmônica deve ser usada para o cálculo da média das taxas
#
# Abaixo está um teste da função `rate_mean_case3`. A função recebe uma lista de tuplas 'data' onde cada tupla é composta por um numerador e um denominador. A função retorna a média da taxa desses valores.

# %%
# Exemplo do uso da média de taxas (Caso 3) para o seguinte conjunto de dados:

data = [(2, 10), (2, 16), (2, 20)]

mean = mean_rate_case3(data)

print(f'Média de taxas: {round(mean,2)}')
# Out:
# Média de taxas: 0.13

# %% [markdown]
# #### Implementação ADBib

# %% [markdown]
# Implementar uma função que, dada uma amostra, analise os critérios para selecionar o cálculo mais apropriado para encontrar a média.

# %% [markdown]
# Abaixo está um teste da função `select_appropriate_mean`, no qual a função é utilizada para calcular a média mais apropriada para diferentes conjuntos de dados.
#
# Ela possui parâmetros opcionais para considerar casos de média de taxas (physical=True), média ponderada (weight=True) e média harmônica (rates=True). Se nenhum desses parâmetros for fornecido e todos os valores forem positivos, a função selecionará a média geométrica, caso algum valor seja zero ou negativo, a média aritmética será selecionada por padrão.

# %%
# Em uma amostra foram registradas a duração (em minutos) de 10 chamadas VoIP: 
data = [2.5, 3.5, 2.8, 1.9, 2.4, 2.6, 3.4, 2.8, 3.6, 2.5]

mean, type_mean = select_appropriate_mean(data)
print(f'A média mais adequada para os dados é: {type_mean} = {mean}')
# Out:
# A média mais adequada para os dados é: geometric = 2.75

# %%
# A amostra a seguir descreve (notas, créditos) de um estudante.
data = [(7, 4), (8, 2), (6, 2), (9, 2), (8, 4), (9, 4)]

mean, type_mean = select_appropriate_mean(data,weight=True)

print(f'A média mais adequada para os dados é: {type_mean} = {mean}')
# Out:
# A média mais adequada para os dados é: weighted = 7.89

# %%
# Observou-se os seguintes valores de uma variável em um experimento:
data = [18, 13, 11, 8, 10, 58, 12]

mean, type_mean = select_appropriate_mean(data)

print(f'A média mais adequada para os dados é: {type_mean} = {mean}')
# Out:
# A média mais adequada para os dados é: geometric = 14.63

# %%
# Considere o conjunto de medidas (em MFLOPS) obtidas em um experimento. 
data = [405, 367, 405, 419, 388]

mean, type_mean = select_appropriate_mean(data,rates=True)

print(f'A média mais adequada para os dados é: {type_mean} = {mean}')
# Out:
# A média mais adequada para os dados é: harmonic = 395.98

# %%
# Dado a amostra dos resultados das medições da taxa de perdas de trasmissão, onde o primeiro valor é a taxa de perda (em %) e o segundo valor é a duração da medição (em segundos) .
data = [(3.0, 100), (5.0, 100), (4.2, 100), (5.2, 100), (8.6, 200)]

mean, type_mean = select_appropriate_mean(data,physical=True)

print(f'A média mais adequada para os dados é: {type_mean} = {round(mean*100,2)}%')
# Out:
# A média mais adequada para os dados é: mean rate (case 1) = 4.33%

# %%
# Dado a amostra dos resultados das medições da taxa de perdas de trasmissão, onde o primeiro valor é a taxa de perda (em %) e o segundo valor é a duração da medição (em segundos) .
data = [(3.0, 100), (5.0, 100), (4.2, 100), (5.2, 100), (8.6, 100)]

mean, type_mean = select_appropriate_mean(data,physical=True)

print(f'A média mais adequada para os dados é: {type_mean} = {round(mean*100,2)}%')
# Out:
# A média mais adequada para os dados é: mean rate (case 2) = 5.2%

# %%
# Exemplo do uso da média de taxas (Caso 3) para o seguinte conjunto de dados:
data = [(2, 10), (2, 16), (2, 20)]

mean, type_mean = select_appropriate_mean(data,physical=True)

print(f'A média mais adequada para os dados é: {type_mean} = {round(mean,2)}')
# Out:
# A média mais adequada para os dados é: mean rate (case 3) = 0.13

# %% [markdown]
# #### Mediana

# %% [markdown]
# Abaixo está um teste da função `median`. A função recebe uma lista de valores 'data' e retorna a mediana desses valores.

# %%
# Dado a seguinte amostra contendo o número de contatos no Facebook de alguns amigos:

data = [108, 103, 252, 121, 93, 57, 40, 53, 22, 116, 98]

median_value = median(data)

print(f'A mediana do número de contatos no Facebook é: {median_value}')
# Out:
# A mediana do número de contatos no Facebook é: 98

# %%
# O exemplo acima contém um número ímpar de elementos, no qual a mediana é o valor central da amostra ordenada.

# Abaixo temos um exemplo com um número par de elementos, onde a mediana é a média aritmética dos dois valores centrais da amostra ordenada:

data = [15, 15, 27, 32, 32, 44]

median_value = median(data)

print(f'A mediana do conjunto de dados é: {median_value}')
# Out:
# A mediana do conjunto de dados é: 29.5

# %% [markdown]
# **Conclusão**
#
# A mediana é uma medida de tendência central valiosa e versátil, especialmente em situações onde a média aritmética pode ser enganosa devido à presença de outliers ou assimetria nos dados. É importante considerar o tipo de dados e a forma da distribuição ao escolher a medida de tendência central mais adequada para representar o centro dos dados.

# %% [markdown]
# #### Moda

# %% [markdown]
# Abaixo está um teste da função `mode`. A função recebe uma lista de valores 'data' e retorna a moda desses valores.

# %%
# Dado a seguinte amostra de um experimento de medição:

data = [3, 4, 4, 5, 5, 6, 7, 8, 9, 9, 9, 10, 11, 12, 12, 13]

mode_value = mode(data)

print(f'A moda da amostra é: {mode_value}')
# Out:
# A moda da amostra é: 9

# %% [markdown]
# **Conclusão**
#
# A moda destaca o valor mais frequente em um conjunto de dados, revelando a preferência ou ocorrência dominante. É particularmente útil para dados categóricos ou discretos, onde a média aritmética pode não ser aplicável ou interpretável. É importante considerar que a moda pode não ser única e pode não representar bem a centralidade em distribuições multimodais ou com baixa frequência de repetição.

# %% [markdown]
# ## Medidas de Dispersão

# %% [markdown]
# #### Amplitude

# %% [markdown]
# Abaixo está o teste da função `amplitude` em exercícios propostos nas Notas de Aula 02. A função recebe uma lista de valores 'data' e retorna a amplitude desses valores.

# %% [markdown]
# **Exercício (Slide 30 - Aula 2)**
#
# Calcular a amplitude das amostras dos grupos Y, Z, W e V
#
# Grupo X: 3, 4, 5, 6, 7 <br>
# Grupo Y: 1, 3, 5, 7, 9 <br>
# Grupo Z: 5, 5, 5, 5, 5 <br>
# Grupo W: 3, 5, 5, 5, 7 <br>
# Grupo V: 3, 5, 5, 6, 6 <br>

# %%
groups = {'X': [3, 4, 5, 6, 7], 'Y': [1, 3, 5, 7, 9], 'Z': [5, 5, 5, 5, 5], 'W': [3, 5, 5, 5, 7], 'V': [3, 5, 5, 6, 6]}

for group, data in groups.items():
    amplitude_value = amplitude(data)
    print(f'A amplitude do grupo {group} é: {amplitude_value}')
# Out:
# A amplitude do grupo X é: 4
# A amplitude do grupo Y é: 8
# A amplitude do grupo Z é: 0
# A amplitude do grupo W é: 4
# A amplitude do grupo V é: 3

# %% [markdown]
# **Exercício (Slide 31- Aula 2)**
#
# Um aplicativo foi desenvolvido para registrar o tempo **T** que o celular de um usuário está próximo do celular de outro usuário. Valores da duração de alguns desses contatos (em segundos):
#
# 23,17,18,32,19,27,22,16,24,29
#
# Calcule a amplitude dessa amostra.

# %%
data = [23, 17, 18, 32, 19, 27, 22, 16, 24, 29]

amplitude_value = amplitude(data)

print(f'A amplitude da amostra é: {amplitude_value}')

plot_amplitude(data)
# Out:
# A amplitude da amostra é: 16

# %% [markdown]
# A amplitude dessa amostra é 16, o que indica uma variação relativamente moderada entre os valores. Não há valores extremos que se destacam drasticamente como outliers.

# %% [markdown]
# **Exercício (Slide 32 - Aula 2)**
#
# Suponha que dois usuários não se viam há muito tempo e o aplicativo registrou 1200 segundos de duração do contato. A amostra ficou assim:
#
# 23,17, 18, 32, 19, 27, 22, 16, 24, 1200
#
# Calcule a amplitude dessa amostra.

# %%
# 23,17, 18, 32, 19, 27, 22, 16, 24, 1200

data = [23, 17, 18, 32, 19, 27, 22, 16, 24, 1200]

amplitude_value = amplitude(data)

print(f'A amplitude da amostra é: {amplitude_value}')

plot_amplitude(data)
# Out:
# A amplitude da amostra é: 1184

# %% [markdown]
# **O que podemos dizer sobre essa segunda amostra?**
#
# Ao contrário do exercício anterior, a amplitude dessa amostra é bastante grande (1184), o que indica que há uma grande variação nos valores dos dados. O valor 1200 é significativamente maior do que os outros valores na amostra, o que sugere que ele é um outlier.
#
# Os outliers podem distorcer a percepção da variação dos dados e influenciar medidas de dispersão como a amplitude.
#
# **Conclusão Geral sobre a Amplitude**
#
# A amplitude é uma medida de dispersão útil e simples que pode fornecer uma visão rápida sobre a extensão de um conjunto de dados. No entanto, sua sensibilidade a outliers e a falta de informações sobre a distribuição interna dos dados limita seu uso em análises estatísticas mais detalhadas.

# %% [markdown]
# #### Desvio Padrão

# %% [markdown]
# Abaixo está um teste da função `standard_deviation` em um exercício proposto nas Notas de Aula 02. A função recebe uma lista de valores 'data' e retorna o desvio padrão desses valores.
#
# **Exercício (Slide 34 - Aula 2)**
#
# O analista de redes de uma empresa coletou uma amostra do tempo (em segundos) de acesso a uma página web que alguns usuários observaram em dois dias consecutivos. As observações do primeiro dia foram {45, 74, 56, 98, 32, 97} e as do segundo dia foram {48, 81, 33, 40, 84}. Ache a variância amostral e o desvio-padrão de cada amostra. Faça uma análise comparativa.

# %%
#Primeiro dia
data = [45, 74, 56, 98, 32, 97]

variance_value = variance(data)
std_deviation_value = standard_deviation(data)

print(f'# Primeiro dia\n')
print(f'Variância amostral do primeiro dia: {variance_value}s²')
print(f'Desvio-padrão do primeiro dia: {std_deviation_value}s')
# Out:
# # Primeiro dia
#
# Variância amostral do primeiro dia: 623.33s²
# Desvio-padrão do primeiro dia: 24.97s

# %%
#Segundo dia
data = [48, 81, 33, 40, 84]

variance_value = variance(data)
std_deviation_value = standard_deviation(data)

print(f'# Segundo dia\n')
print(f'Variância amostral do segundo dia: {variance_value}s²')
print(f'Desvio-padrão do segundo dia: {std_deviation_value}s')
# Out:
# # Segundo dia
#
# Variância amostral do segundo dia: 450.16s²
# Desvio-padrão do segundo dia: 21.22s

# %% [markdown]
# A variância amostral e o desvio padrão amostral são medidas de dispersão que indicam o quão espalhados estão os dados em torno da média. A variância amostral é calculada como a soma dos quadrados dos desvios em relação à média, dividida pelo número de observações menos um. O desvio padrão amostral é a raiz quadrada da variância amostral.
#
# **Análise Comparativa do Exercício**
#
# - **Primeiro Dia:**
#
# Variância amostral: 623.33s² <br>
# Desvio-padrão: 24.97s
#
# - **Segundo Dia:**
#
# Variância amostral: 450.16s² <br>
# Desvio-padrão: 21.22s
#
# A variância e o desvio padrão do tempo de acesso no primeiro dia são maiores do que no segundo dia. Isso indica que os tempos de acesso no primeiro dia foram mais dispersos, ou seja, houve uma maior variabilidade nos tempos de carregamento da página web no primeiro dia em comparação com o segundo dia. No segundo dia, os tempos de acesso foram relativamente mais próximos da média.

# %% [markdown]
# #### Coeficiente de Variação

# %% [markdown]
# Abaxo está um teste da função `variation_coefficient` em um exercício proposto nas Notas de Aula 02. A função recebe uma lista de valores 'data' e retorna o coeficiente de variação desses valores.
#
# **Exercício (Slide 36 - Aula 2)**
#
# Um psicultor mediu o tamanho de alguns peixes a fim de monitorar a condição ideal para o consumo. A amostra apresentou os seguintes valores em cm: 76,102,12,39,55,93,98,53,102.
#
# Verifique se o tamanho médio é representativo.

# %%
data = [76, 102, 12, 39, 55, 93, 98, 53, 102]

mean = arithmetic_mean(data)
median_value = median(data)
variance_value = variance(data)
std_deviation_value = standard_deviation(data)
cv_value = coefficient_of_variation(data)

print(f'Tamanho médio: {mean} cm')
print(f'Mediana: {median_value} cm')
print(f'Variância: {variance_value} cm²')
print(f'Desvio-padrão: {std_deviation_value} cm')
print(f'Coeficiente de variação: {cv_value} %')
# Out:
# Tamanho médio: 70.0 cm
# Mediana: 76 cm
# Variância: 915.11 cm²
# Desvio-padrão: 30.25 cm
# Coeficiente de variação: 43.21 %

# %% [markdown]
# Para verificar se o tamanho médio dos peixes é representativo, podemos calcular a média amostral e analisar a dispersão dos dados ao redor dessa média. Para isso, podemos utilizar a variância e o desvio-padrão para avaliar a dispersão.
#
# - **Média amostral:** 70 cm
# - **Variância amostral:** 915.11 cm²
# - **Desvio-padrão amostral:** 30.25 cm
#
# A média de 70 cm é uma medida central, mas a alta variância e o desvio-padrão sugerem uma grande dispersão dos dados. Isso significa que os tamanhos dos peixes variam significativamente em torno da média. A representatividade da média pode ser questionada devido à alta variabilidade dos tamanhos dos peixes na amostra.
#
# A mediana pode fornecer uma visão complementar, pois não é afetada por valores extremos.
#
# - **Mediana:** 76 cm
#
# O coeficiente de variação (CV) é uma medida relativa de dispersão que permite comparar a variabilidade de uma amostra em relação à sua média. Na prática, considera-se que CV > 50% indica alto grau de dispersão e, por consequência, baixa representatividade da média.
#
# - **Coeficiente de Variação:** 43.21%
#
# **Conclusão**
#
# Embora a média seja 70 cm, a alta dispersão indica que muitos valores estão longe da média. A mediana de 76 cm pode ser uma medida mais representativa do tamanho típico dos peixes nesta amostra. A média, acompanhada do desvio-padrão, sugere que há uma variabilidade significativa nos tamanhos dos peixes, o que pode influenciar a representatividade da média como uma medida central.
#
# Um CV de aproximadamente 43.21% indica que a variabilidade dos tamanhos dos peixes é moderada (quase alta) em relação à média. Isso significa que os tamanhos dos peixes na amostra são bastante dispersos ao redor da média.

# %% [markdown]
# #### Quartis

# %% [markdown]
# Abaixo está um teste da função `calculate_quartiles` e da função `interquartile_amp` em um exemplo nas Notas de Aula 02. As funções recebem uma lista de valores 'data' e retorna os quartis desses valores e a amplitude interquartil, respectivamente.
#
# Em seguida, um gráfico de caixa é plotado para visualizar a distribuição dos dados em relação aos quartis.

# %%
# Dado a seguinte amostra de exemplo: 11 16 25 44 46 53 71 88 91 

data = [11, 16, 25, 44, 46, 53, 71, 88, 91]

q1, q2, q3 = calculate_quartile(data)
interquartile_amp_value = interquartile_amp(data)

print(f'Q1: {q1}, Q2: {q2}, Q3: {q3}')
print(f'Amplitude interquartil: {interquartile_amp_value}')
plot_boxplot(data)
# Out:
# Q1: 25, Q2: 46, Q3: 71
# Amplitude interquartil: 46

# %% [markdown]
# **Conclusão**
#
# A amostra de dados apresenta uma distribuição aproximadamente simétrica, com uma dispersão moderada em torno da mediana. A maior parte dos dados está concentrada na parte inferior da distribuição, e não há indícios de outliers.

# %% [markdown]
# #### Implementação ADBib

# %% [markdown]
# Implementar uma função que, dada uma amostra, encontre as medidas de dispersão estudadas. Testar a função com os exercícios nos slides anteriores.
#
# A função `dispersion_measures` recebe uma amostra de dados e retorna um dicionário contendo as medidas de dispersão estudadas.
#
# Para evitar a execução de muitas células, foi escolhido o exercício do slide 34 - Aula 2 (analista de redes) para testar a função, pois ele apresenta duas amostas de dados.
#
# **Exercício (Slide 34 - Aula 2)**
#
# O analista de redes de uma empresa coletou uma amostra do tempo (em segundos) de acesso a uma página web que alguns usuários observaram em dois dias consecutivos. As observações do primeiro dia foram {45, 74, 56, 98, 32, 97} e as do segundo dia foram {48, 81, 33, 40, 84}.

# %%
# Primeiro dia

data = [45, 74, 56, 98, 32, 97]


print(f'# Primeiro dia\n')

dispersion_measures(data,unit='s')
# Out:
# # Primeiro dia
#
# Amplitude: 66 s
# Variância Amostral: 623.33 s²
# Desvio Padrão Amostral: 24.97 s
# Coeficiente de Variação (%): 37.27
# Quartis: (45, 65.0, 97)
# Amplitude Interquartil: 52 s

# %%
# Segundo dia

data = [48, 81, 33, 40, 84]

print(f'# Segundo dia\n')
dispersion_measures(data, unit='s')
# Out:
# # Segundo dia
#
# Amplitude: 51 s
# Variância Amostral: 450.16 s²
# Desvio Padrão Amostral: 21.22 s
# Coeficiente de Variação (%): 37.1
# Quartis: (40, 48, 81)
# Amplitude Interquartil: 41 s

# %% [markdown]
# **Análise dos Resultados de cada Medida de Dispersão**
#
# **Amplitude:**
#
# * **Dia 1:** 66 segundos
# * **Dia 2:** 51 segundos
#
# A amplitude no primeiro dia foi maior, indicando que a diferença entre o maior e o menor tempo de acesso foi maior nesse dia. Isso sugere uma maior variabilidade nos tempos de acesso no primeiro dia.
#
# **Variância Amostral:**
#
# * **Dia 1:** 623.33 segundos²
# * **Dia 2:** 450.16 segundos²
#
# A variância amostral no primeiro dia foi maior, indicando que os tempos de acesso nesse dia estão mais dispersos em relação à média do que no segundo dia.
#
# **Desvio Padrão Amostral:**
#
# * **Dia 1:** 24.97 segundos
# * **Dia 2:** 21.22 segundos
#
# O desvio padrão amostral no primeiro dia foi maior, confirmando a maior dispersão dos tempos de acesso nesse dia em relação à média.
#
# **Coeficiente de Variação (%):**
#
# * **Dia 1:** 37.27%
# * **Dia 2:** 37.1%
#
# O coeficiente de variação é uma medida de dispersão relativa que permite comparar a variabilidade de conjuntos de dados com diferentes médias. Neste caso, os coeficientes de variação são próximos, indicando que a variabilidade relativa dos tempos de acesso em relação à média é similar nos dois dias.
#
# **Quartis:**
#
# * **Dia 1:** Q1 = 45, Q2 = 65.0, Q3 = 97
# * **Dia 2:** Q1 = 40, Q2 = 48, Q3 = 81
#
# Os quartis mostram a distribuição dos tempos de acesso em cada dia. No primeiro dia, os tempos de acesso são mais espalhados, com uma maior diferença entre Q1 e Q3. No segundo dia, os tempos de acesso estão mais concentrados em torno da mediana (Q2).
#
# **Amplitude Interquartil (IQR):**
#
# * **Dia 1:** 52 segundos
# * **Dia 2:** 41 segundos
#
# A amplitude interquartil (IQR) é a diferença entre o terceiro quartil (Q3) e o primeiro quartil (Q1). No primeiro dia, a IQR é maior, indicando uma maior dispersão dos tempos de acesso no intervalo central (50% dos dados) em comparação com o segundo dia.

# %% [markdown]
# #### Exercício Vingadores da Marvel (Slide 44 - Aula 2)

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/fivethirtyeight/data/master/avengers/avengers.csv'
df = pd.read_csv(url,encoding='latin-1')

# Selecionar as coluna de interesse
appearances = df['Appearances'].dropna().tolist()
names = df['Name/Alias'].tolist()

# Criar um novo DataFrame com as colunas de interesse
df_appearances = pd.DataFrame({'Name/Alias': names, 'Appearances': appearances})

# Ordenar o DataFrame pela coluna 'Appearances' em ordem decrescente
df_appearances = df_appearances.sort_values(by='Appearances', ascending=False)

# Exibir as 10 primeiras linhas do DataFrame
print(df_appearances.head(10))

plot_histogram_avengers(appearances, bins=100)
# Out:
#                      Name/Alias  Appearances
# 73        Peter Benjamin Parker         4333
# 6                 Steven Rogers         3458
# 92        James "Logan" Howlett         3130
# 2   Anthony Edward "Tony" Stark         3068
# 4                  Thor Odinson         2402
# 40         Benjamin Jacob Grimm         2305
# 57                Reed Richards         2125
# 3           Robert Bruce Banner         2089
# 17               Henry P. McCoy         1886
# 58   Susan Richards (nee Storm)         1761

# %% [markdown]
# **Conclusão Sobre o Histograma**
#
# O histograma gerado a partir dos dados de aparições dos Vingadores mostra a distribuição das aparições ao longo de diferentes valores.
#
# Podemos observar algumas características importantes:
#
# - **Assimetria à Direita:** O histograma apresenta uma cauda longa à direita. Isso indica que há alguns Vingadores com um número muito alto de aparições, mas a maioria possui um número menor de aparições.
# - **Concentração de Valores:** A maioria dos valores está concentrada no intervalo mais baixo de aparições, com a frequência diminuindo à medida que os valores aumentam.
# - **Presença de Outliers:** Existem valores excepcionalmente altos (por exemplo, 3130, 3458, e 4333), que são outliers e afetam a média.

# %%
# Medidas de Tendência Central

mean_value = arithmetic_mean(appearances)
print(f'Média Aritmética: {mean_value}')

median_value = median(appearances)
print(f'Mediana: {median_value}')

mode_value = mode(appearances)
print(f'Moda: {mode_value}')
# Out:
# Média Aritmética: 414.05
# Mediana: 132
# Moda: 108

# %% [markdown]
# **Conclusão Sobre as Medidas de Tendência Central**
#
# Com base no conjunto de dados, foi obtido as seguintes medidas centrais:
#
# - Média Aritmética: 414,05
# - Mediana: 132
# - Moda: 108
#
# A média aritmética é muito mais alta do que a mediana devido à presença de outliers. A mediana, sendo 132, é uma medida central mais representativa para esse conjunto de dados assimétrico. A moda de 108 indica o valor mais frequente, mas não é tão útil neste caso devido à natureza contínua dos dados.
#
# Em conjuntos de dados muito assimétricos, a mediana é a medida de tendência central mais adequada.
#
# **Por que a mediana é melhor em casos de assimetria?**
#
# - **Robustez a Outliers:** A mediana não é influenciada por valores extremos (outliers), que são comuns em distribuições assimétricas. Ela representa o valor central da distribuição, independentemente de valores muito altos ou muito baixos.
# - **Representatividade:** Em distribuições assimétricas, a média aritmética pode ser "puxada" para o lado da cauda mais longa, não representando bem o centro dos dados. A mediana, por outro lado, permanece no centro da distribuição, mesmo com a assimetria.

# %%
# Medidas de Dispersão

amplitude_value = amplitude(appearances)

print(f'Amplitude: {amplitude_value}')

# Personagem com maior número de aparições
max_value = max(appearances)
max_index = appearances.index(max_value)
max_character = names[max_index]

print(f'Personagem com maior número de aparições: {max_character} ({max_value} aparições)')

# Personagem com menor número de aparições

min_value = min(appearances)
min_index = appearances.index(min_value)
min_character = names[min_index]

print(f'Personagem com menor número de aparições: {min_character} ({min_value} aparições)')

plot_amplitude(appearances)
# Out:
# Amplitude: 4331
# Personagem com maior número de aparições: Peter Benjamin Parker (4333 aparições)
# Personagem com menor número de aparições: Moira Brandon (2 aparições)

# %%
q1, q2, q3 = calculate_quartile(appearances)
print(f'Q1: {q1}, Q2: {q2}, Q3: {q3}')

interquartile_amp_value = interquartile_amp(appearances)
print(f'Amplitude interquartil: {interquartile_amp_value}')

plot_boxplot(appearances)
# Out:
# Q1: 58, Q2: 132, Q3: 491
# Amplitude interquartil: 433

# %%
variance_value = variance(appearances)
std_deviation_value = standard_deviation(appearances)
cv_value = coefficient_of_variation(appearances)

print(f'Variância: {variance_value}')
print(f'Desvio-padrão: {std_deviation_value}')
print(f'Coeficiente de variação: {cv_value}%')
# Out:
# Variância: 457016.01
# Desvio-padrão: 676.03
# Coeficiente de variação: 163.27%

# %% [markdown]
# **Conclusão Sobre as Medidas de Dispersão**
#
# **Amplitude:**
#
# A amplitude total de 4331 indica uma grande dispersão entre o menor e o maior valor da amostra. Isso significa que há uma grande diferença no número de aparições entre os Vingadores menos e mais populares.
#
# **Amplitude Interquartil (IQR):**
#
# A amplitude interquartil (IQR) de 433 indica que os 50% centrais dos dados (entre o primeiro e o terceiro quartis) estão espalhados em um intervalo de 433 aparições. Isso sugere que há uma variabilidade considerável no número de aparições mesmo entre os Vingadores que não são os mais ou menos populares.
#
# **Relação entre Amplitude Total e IQR:**
#
# A amplitude interquartil (433) representa cerca de 9.98% da amplitude total (4331). Isso significa que, embora a maior parte dos Vingadores tenha um número de aparições dentro de um intervalo relativamente pequeno (IQR), existem alguns valores extremos (outliers) que aumentam significativamente a amplitude total.
#
# **Análise no Diagrama de Caixa (Boxplot):**
#
# - **Assimetria:** A distribuição do número de aparições dos Vingadores é altamente assimétrica à direita (positiva). A caixa (que representa 50% dos dados centrais) está comprimida na parte inferior do gráfico, e o bigode superior é muito mais longo que o bigode inferior, indicando a presença de valores muito altos (outliers).
#
# - **Outliers:** Há vários outliers, representados pelos pontos individuais acima do bigode superior. Esses outliers são os Vingadores que aparecem em um número muito maior de histórias do que a maioria dos outros personagens.
#
# - **Concentração:** A maioria dos Vingadores (50% dos valores centrais) tem um número relativamente baixo de aparições, como indicado pela caixa comprimida na parte inferior do gráfico.
#
# - **Dispersão:** A distância entre os quartis (Q1 e Q3) é relativamente grande, o que indica uma variabilidade considerável no número de aparições mesmo entre os Vingadores que não são outliers.
#
# **Variância, Desvio Padrão e Coeficiente de Variação:**
#
# A análise das medidas de dispersão (variância, desvio padrão e coeficiente de variação) para o conjunto de dados sobre o número de aparições dos Vingadores revela uma elevada heterogeneidade na distribuição dos dados.
#
# A variância amostral de 457.016,01 indica que os valores de aparições estão bastante dispersos em relação à média, com uma grande variabilidade entre o número de aparições dos diferentes personagens.
#
# O desvio padrão amostral de 676,03, que corresponde à raiz quadrada da variância, reforça essa dispersão, mostrando que, em média, os valores de aparições se distanciam da média em aproximadamente 676 unidades.
#
# O coeficiente de variação de 163,27% indica uma alta variabilidade relativa, evidenciando que o desvio padrão é consideravelmente maior que a média. Isso significa que a média não é uma medida muito representativa da tendência central dos dados, devido à grande dispersão e à presença de valores extremos (outliers).
#
# Por fim, essas medidas de dispersão confirmam a conclusão anterior de que a distribuição do número de aparições dos Vingadores é bastante desigual, com alguns personagens tendo um número muito maior de aparições do que outros. Essa informação pode ser relevante para entender a popularidade e a importância dos diferentes personagens no universo Marvel.

# %% [markdown]
# ## Intervalo de Confiança

# %% [markdown]
# Abaixo está um teste da função `confidence_interval` em dois exercícios propostos nas Notas de Aula 02. A função recebe uma lista de valores 'data', e o grau de confiaça desejado, e retorna o intervalo de confiança da amostra.

# %% [markdown]
# #### Exercício (Slide 53 - Aula 2)

# %% [markdown]
# Construir um IC com níveis de confiança de 90%, 95% e 99%, para os seguintes dados coletados em um experimento:
# 177, 122, 128, 191, 180, 142, 197, 196, 67, 160, 167, 138, 107, 188, 102, 116, 138, 114, 188, 176, 148, 175, 169, 203, 135, 142, 168, 181, 168, 150, 132, 196, 88, 177, 164, 118, 178, 102, 156, 114

# %%
data = [177, 122, 128, 191, 180, 142, 197, 196, 67, 160, 167, 138, 107, 188, 102, 116, 138, 114, 188, 176, 148, 175, 169,
            203, 135, 142, 168, 181, 168, 150, 132, 196, 88, 177, 164, 118, 178, 102, 156, 114]
confidence_levels = [0.9, 0.95, 0.99]
for level in confidence_levels:
    print(f"Intervalo de confiança com Nível de Confiança de {level}: {confidence_interval(data, level)}")
# Out:
# Intervalo de confiança com Nível de Confiança de 0.9: (142.73, 160.17)
# Intervalo de confiança com Nível de Confiança de 0.95: (141.06, 161.84)
# Intervalo de confiança com Nível de Confiança de 0.99: (137.79, 165.11)

# %% [markdown]
# **Análise dos Resultados**
# Para a seguinte amostra, tem-se os dados de
# * **Média aritmética:** 151.45
#
# Um intervalo de confiança é uma faixa de valores em torno de uma estimativa estatística que tem uma alta probabilidade de conter o verdadeiro valor do parâmetro populacional. Em outras palavras, é uma medida da incerteza associada a uma estimativa estatística.
# Quando se calcula uma estimativa estatística, como a média ou a proporção de uma amostra, geralmente se deseja ter uma ideia de quão confiáveis são tais estimativas. Um intervalo de confiança fornece essa informação, indicando a faixa de valores dentro da qual acredita-se que o verdadeiro valor do parâmetro populacional esteja com uma certa probabilidade.
#
# Logo, conclui-se que o verdadeiro valor da média do universo, a partir do grau especificado, esteja dentro das faixas geradas pela função. Nota-se que quanto maior o grau de certeza desejável, maior é o intervalo de confiança, oq eu faz total sentido matemático.

# %% [markdown]
# #### Exercício (Slide 56 - Aula 2)

# %% [markdown]
# Construir um IC com nível de confiança de 95%, para a seguinte amostra coletada em um experimento: -0.04, -0.19, 0.14, -0.09, -0.14, 0.19, 0.04, 0.09

# %%
data = [ -0.04, -0.19, 0.14, -0.09, -0.14, 0.19, 0.04, 0.09]
print(confidence_interval(data, 0.95))
# Out:
# (-0.12, 0.12)

# %% [markdown]
# **Análise dos Resultados**
# Para a seguinte amostra, tem-se os dados de
# * **Média aritmética:** 0
#
# Logo, conclui-se que o verdadeiro valor da média do universo, a partir do grau especificado (95%), esteja dentro da faixa geradas pela função.

# %% [markdown]
# ## Teste de Média Zero

# %% [markdown]
# #### Exercício (Slide 61 - Aula 2)

# %% [markdown]
# Dois sistemas (A e B) foram submetidos a seis cargas similares. As
# observações da métrica de interesse para os dois sistemas aparecem na
# tabela abaixo. Um dos sistemas é melhor que o outro? Argumente com
# base em um nível de confiança de 90%, 95% e 99%.
#
# * **Sistema A:** 5.4, 16.6, 0.6, 1.4, 0.6, 7.3
# * **Sistema B:** 19.1, 3.5, 3.4, 2.5, 3.6, 1.7

# %%
confidence_degree = [0.9, 0.95, 0.99]
sys_A = [5.4, 16.6, 0.6, 1.4, 0.6, 7.3]
sys_B = [19.1, 3.5, 3.4, 2.5, 3.6, 1.7]
for degree in confidence_degree:
    print(f"Grau de confiança: {degree} ; Amostras são significativamente similares: {zero_mean_test(sys_A, sys_B, degree)}")
# Out:
# Grau de confiança: 0.9 ; Amostras são significativamente similares: True
# Grau de confiança: 0.95 ; Amostras são significativamente similares: True
# Grau de confiança: 0.99 ; Amostras são significativamente similares: True

# %% [markdown]
# **Experimento**
#
# A partir das cargas dos dois sistemas, obteve-se uma lista com a diferença entre as cargas e calculou-se seu intervalo de confiança.
# Para os três intervalos de confiança, observa-se que o 0 está incluso.
#
# **Conclusões**
#
# Pelo Teste de Média Zero, pode-se afirmar que as amostras são estatísticamente similares para os três graus de confiança (90%, 95% e 99%). Contudo, é impossível afirmar se um dos sistemas "é melhor que o outro".

# %% [markdown]
# #### Exercício (Slide 62 - Aula 2)

# %% [markdown]
# A diferença de tempo de execução de duas implementações do mesmo
# algoritmo foi medida em sete cargas de trabalho semelhantes. As
# diferenças obtidas foram: {1,5; 2,6; -1,8; 1,3; -0,5; 1,7; 2,4}. Podemos
# dizer com 99% de confiança que uma implementação é superior à outra?

# %%
diff = [1.5, 2.6, -1.8, 1.3, -0.5, 1.7, 2.4]
confidence_interval(diff, 0.99)
# Out:
# (-1.04, 3.1)

# %% [markdown]
# Com base no Teste da Média Zero, pode-se afirmar que as amostras são estatíticamente similares com um grau de confiança de 99%. Contudo, não se pode afirmar que "uma implementação é superior à outra"

# %% [markdown]
# #### Exercício (Slide 65 - Aula 2)

# %% [markdown]
# O tempo de processador consumido na execução de uma determinada aplicação foi medido em dois sistemas. Os tempos nos sistema A e B estão registrados na tabela a seguir. Podemos afirmar que os dois sistemas são significativamente diferentes? Utilizem 90%, 95% e 99% como nível de confiança.
#
# * **A** 5.3, 16, 0.6, 1.4, 0.6, 7.7, 3.6, 2.4, 12, 6, 57, 2, 1, 4, 6, 4, 8, 1
# * **B** 19, 3.5, 3.3, 2.5, 3.6, 1.7, 12, 2, 8, 1, 1, 4

# %%
confidence_degree = [0.9, 0.95, 0.99]
sys_a = [5.3, 16, 0.6, 1.4, 0.6, 7.7, 3.6, 2.4, 12, 6, 57, 2, 1, 4, 6, 4, 8, 1]
sys_b = [19, 3.5, 3.3, 2.5, 3.6, 1.7, 12, 2, 8, 1, 1, 4]
for confidence in confidence_degree:
    print(f"Amostras são significativamente similares: {zero_mean_test(sys_a, sys_b, confidence)}")
# Out:
# Amostras são significativamente similares: False
# Amostras são significativamente similares: False
# Amostras são significativamente similares: True

# %% [markdown]
# Observa-se que apenas com o grau de confiança de 99% as amostras são significativamente similares, pois é o grau de confiança que apresenta o maior intervalo, e o único no qual o 0 está incluso. Portanto, a analise dos dados mostra-se inconclusiva.

# %% [markdown]
# ## Distribuição de Probabilidade

# %% [markdown]
# Abaixo está um teste da função `calcular_estatisticas_e_plotar_fdp` em um exemplo no Slide 19/20 nas notas de aula 03. A função recebe uma lista 'valores' que a variável aleatória pode assumir e uma lista 'probabilidades' correspondente a cada valor. A função retorna as estatísticas da distribuição e plota a função  função distribuição de probabilidade.

# %%
# Exemplo de uso (dados do exemplo Slide 19/20)
valores = [-1, 1, 2, 3]
probabilidades = [1/4, 1/8, 1/8, 1/2]
calcular_estatisticas_e_plotar_fdp(valores, probabilidades)
# Out:
# Valor Esperado (Média): 1.625
# Valor Esperado Quadrado: 5.375
# Variância: 2.734

# %% [markdown]
# **Conclusão**
#
# - **Tendência Central:** O valor esperado (média) de X é 1,625. Isso significa que, em média, espera-se que a variável aleatória assuma valores próximos a 1,625.
#
# - **Dispersão:** A variância de X é 2,734. Este valor indica que os valores de X estão moderadamente dispersos em torno da média. Quanto maior a variância, maior a variabilidade dos valores em relação à média.
#
# - **Assimetria:** A distribuição de probabilidade de X é assimétrica à direita (positiva). Isso pode ser observado no gráfico da FDP, onde a probabilidade é maior para valores menores de X e diminui à medida que X aumenta.
#
# - **Valores Mais Prováveis:** O valor mais provável de X é 3, com uma probabilidade de 1/2. Os valores -1, 1 e 2 têm probabilidades menores, indicando que são menos prováveis de ocorrerem.

# %% [markdown]
# #### Exercícios da Literatura para testar a Função de Distribuição de Probabilidade

# %% [markdown]
# **Exercício 1:** Distribuição de Probabilidade de Falhas em um Sistema
#
# - Referência: Montgomery, Douglas C., and George C. Runger. Applied statistics and probability for engineers. John wiley & sons, 2020.
#
# Suponha que um sistema eletrônico tenha três componentes que podem falhar independentemente. Seja X a variável aleatória que representa o número de componentes que falham. A distribuição de probabilidade de X é dada por:
#
# P(X = 0) = 0.8 (nenhum componente falha) <br>
# P(X = 1) = 0.15 (um componente falha) <br>
# P(X = 2) = 0.04 (dois componentes falham) <br>
# P(X = 3) = 0.01 (três componentes falham)

# %%
valores = [0, 1, 2, 3]
probabilidades = [0.8, 0.15, 0.04, 0.01]

calcular_estatisticas_e_plotar_fdp(valores, probabilidades)
# Out:
# Valor Esperado (Média): 0.260
# Valor Esperado Quadrado: 0.400
# Variância: 0.332

# %% [markdown]
# **Conclusão do Exercício 1**
#
# - A probabilidade de que pelo menos um componente do sistema eletrônico falhe é de 0.2 (1 - 0.8), ou seja, 20%. Isso significa que há uma chance relativamente baixa de falha total do sistema.
#
# - Em média, espera-se que 0.26 componentes falhem em cada sistema. Isso indica que, na maioria das vezes, nenhum ou apenas um componente falhará.
#
# -  A variância de 0.332 indica que há uma certa dispersão em torno do número esperado de falhas. Ou seja, embora a média seja de 0.26, o número real de componentes que falham pode variar de sistema para sistema.

# %% [markdown]
# **Exercício 2: Seleção de Bolas Numeradas**
# Neste exemplo, uma sacola contém bolas numeradas com \(2\), \(4\) ou \(6\). A variável aleatória \(X\) representa o número obtido ao selecionar uma bola ao acaso. A função de probabilidade é dada por \(P(X=x) = \frac{8x - x^2}{40}\).
#
# - \(X = 2\): \(P(X=2) = \frac{12}{40} = 0.3\)
# - \(X = 4\): \(P(X=4) = \frac{16}{40} = 0.4\)
# - \(X = 6\): \(P(X=6) = \frac{12}{40} = 0.3\)
#
# Referência: [Discrete Random Variables & Probability Distribution Functions - Radford Mathematics](https://www.radfordmathematics.com)

# %%
valores = [2, 4, 6]
probabilidades = [0.3, 0.4, 0.3]
calcular_estatisticas_e_plotar_fdp(valores, probabilidades)
# Out:
# Valor Esperado (Média): 4.000
# Valor Esperado Quadrado: 18.400
# Variância: 2.400

# %% [markdown]
# **Conclusão do Exercício 2**
#
# - O valor esperado de 4.000 indica que, em média, ao selecionar uma bola da sacola, espera-se obter o número 4. Este valor é consistente com a probabilidade maior associada ao número 4, como calculado pela função de probabilidade.
#
# - O valor esperado do quadrado de \(X\) é 18.400. Este valor é utilizado para calcular a variância da variável aleatória. Ele reflete a média dos quadrados dos valores possíveis de \(X\) ponderados pelas suas respectivas probabilidades.
#
# - A variância de 2.400 indica a dispersão dos valores de \(X\) em torno da média. Uma variância de 2.400 mostra que há uma certa dispersão dos valores em torno da média de 4, o que é esperado dado que \(X\) pode assumir valores tão baixos quanto 2 e tão altos quanto 6.
#
#
# Os resultados indicam que a variável aleatória \(X\) está centrada em torno do valor 4, com uma moderada dispersão dos valores ao redor da média. Este comportamento é coerente com as probabilidades atribuídas aos valores possíveis de \(X\), onde o valor 4 tem a maior probabilidade (0.4) comparado aos valores 2 e 6 (ambos com probabilidade de 0.3).

# %% [markdown]
# #### Exercício (Slide 22 - Aula 3)

# %%
# Suponha que a V.A. X represente a idade de um calouro do IComp selecionado aleatoriamente. A tabela seguinte mostra a sua distribuição de probabilidade. Encontre a média e a variância de X

# x 16 17 18 19 20 21 22
# p(x) 0,05 0,10 0,15 0,25 0,20 0,15 0,10

valores = [16, 17, 18, 19, 20, 21, 22]
probabilidades = [0.05, 0.10, 0.15, 0.25, 0.20, 0.15, 0.10]

calcular_estatisticas_e_plotar_fdp(valores, probabilidades)
# Out:
# Valor Esperado (Média): 19.300
# Valor Esperado Quadrado: 375.100
# Variância: 2.610

# %% [markdown]
# **Conclusão**
#
# A média de idade dos calouros do IComp é de 19.3 anos. Isso significa que, se selecionarmos um calouro aleatoriamente, a idade mais provável de se encontrar está próxima de 19.3 anos.
#
#  variância de 2.61 indica que há uma pequena dispersão nas idades dos calouros em torno da média. A maioria dos calouros tem idades próximas a 19 ou 20 anos.
#
# A moda da distribuição é 19 anos, que é a idade com maior probabilidade de ser encontrada em um calouro selecionado aleatoriamente.
#
# A distribuição de probabilidade é aproximadamente simétrica em torno da média, com um leve achatamento no topo. Isso indica que as idades dos calouros estão concentradas em torno da média, com pouca variação.

# %% [markdown]
# #### Exercício (Slide 23 - Aula 3)

# %%
# No vídeo game The Kings of Madra, os usuários resolvem quebra-cabeças lógicos
# para se tornarem mais poderosos e influentes. O número de pontos de experiência
# ganhos em cada nível é uma variável aleatória (Y), e é o quadrado do número de
# quebra-cabeças

# y 0 1 4 9 16 25
# p(y) 0,01 0,05 ? 0,25 0,35 0,30

valores = [0, 1, 4, 9, 16, 25]
probabilidades = [0.01, 0.05, 0, 0.25, 0.35, 0.30]

# Determine:

# (a) p(4)

probabilidades[2] = 1 - sum(probabilidades)  # A soma das probabilidades deve ser 1
print(f"(a) p(4) = {probabilidades[2]:.2f}")

# (b) P( 1 <= Y <= 16 )

prob_b = sum(probabilidades[i] for i in range(len(valores)) if 1 <= valores[i] <= 16)
print(f"(b) P(1 <= Y <= 16) = {prob_b:.2f}")

# (c) P( 1 < Y < 16 )
prob_c = sum(probabilidades[i] for i in range(len(valores)) if 1 < valores[i] < 16)
print(f"(c) P(1 < Y < 16) = {prob_c:.2f}")

calcular_estatisticas_e_plotar_fdp(valores, probabilidades)
# Out:
# (a) p(4) = 0.04
# (b) P(1 <= Y <= 16) = 0.69
# (c) P(1 < Y < 16) = 0.29
# Valor Esperado (Média): 15.560
# Valor Esperado Quadrado: 298.040
# Variância: 55.926

# %% [markdown]
# **Conclusão**
#
# A análise da distribuição de probabilidade dos pontos de experiência (Y) no jogo "The Kings of Madra" revela informações importantes sobre a dinâmica do jogo e a progressão dos jogadores.
#
# (a) p(4) = 0.04
#
# - Isso significa que a probabilidade de um usuário ganhar 4 pontos de experiência, que ocorre quando ele completa 2 quebra-cabeças, é de 4%. Essa é a menor probabilidade entre todos os valores possíveis de Y.
#
# (b) P(1 <= Y <= 16) = 0.69
#
# - Essa é a probabilidade de um usuário ganhar entre 1 e 16 pontos de experiência, o que ocorre quando ele completa de 1 a 4 quebra-cabeças. Isso representa a maioria dos casos, já que a probabilidade total é de 69%.
#
# (c) P(1 < Y < 16) = 0.29
#
# - Essa probabilidade é um pouco menor que a anterior, pois exclui o caso em que o usuário ganha exatamente 16 pontos de experiência, ou seja, quando ele completa exatamente 4 quebra-cabeças. Isso mostra que completar exatamente 4 quebra-cabeças é um evento menos provável do que completar de 1 a 3 quebra-cabeças.
#
# **Valor Esperado (Média):** O valor esperado de 15.56 indica a média de pontos de experiência que um jogador pode esperar ganhar por nível, a longo prazo. Em outras palavras, se um jogador jogar muitos níveis, a média dos pontos obtidos em cada nível tenderá a se aproximar de 15.56.
#
# **Valor Esperado ao Quadrado:** O valor esperado ao quadrado (298.04) é uma medida auxiliar utilizada no cálculo da variância. Ele representa a média dos quadrados dos pontos de experiência que um jogador pode esperar ganhar por nível.
#
# **Variância:** A variância de 55.926 indica a dispersão dos pontos de experiência em torno do valor esperado. Uma variância alta significa que os pontos de experiência obtidos em cada nível podem variar bastante, enquanto uma variância baixa indica que os pontos tendem a ser mais próximos do valor esperado.
#
# Em resumo, a análise das estatísticas da variável aleatória Y (pontos de experiência) no jogo "The Kings of Madra" revela que os jogadores podem esperar ganhar em média 15.56 pontos por nível, com uma variação considerável em torno desse valor. Essa informação pode ser útil para os desenvolvedores do jogo avaliarem e ajustarem o sistema de progressão, garantindo uma experiência equilibrada e divertida para os jogadores.

# %% [markdown]
# ## Variáveis Aleatórias Discretas

# %% [markdown]
# #### Exercício (Slide 31 - Aula 3)

# %% [markdown]
# Cerca de 75% de estudantes do IComp acompanham as aulas síncronas através de um notebook, enquanto que 25% acessam via celular. Suponha que em uma aula síncrona, o professor seleciona aleatoriamente 10 estudantes. Qual a probabilidade de que exatamente 6 estudantes estejam usando notebook.
#
# Por se tratar de um problema de n acontecimentos onde se quer obter uma taxa de sucesso em cada uma, utiliza-se a variável aleatória binomial. Tem-se os cálculos para os 10 estudantes e a taxa de sucesso de 6 deles. p = 75%, pois é a porcentagem de estudantes que acompanham as aulas síncronas.

# %%
print(f'{binomial_pmf(10, 0.75, 6)*100}%')
# Out:
# 15.0%

# %% [markdown]
# **Resultados e Discussões**
#
# Observa-se que aproximadamente 15% dos estudantes de que exatamente 6 estudantes estejam usando o notebook.

# %% [markdown]
# #### Exercício (Slide 35 - Aula 3)

# %% [markdown]
# Suponha que a probabilidade de perda em um link seja 10% e que perdas de pacotes sejam independentes, embora isso aconteça raramente na prática. Quando um pacote é perdido, isso é detectado e o pacote retransmitido até que seja recebido corretamente. Qual é a probabilidade de um pacote ser retransmitido exatamente em 1, 2 e 3 vezes?
#
# Por se tratar de um problema de repetição, utiliza-se a variável aleatória geométrica. Tem-se os cálculos para as três retransmissões (i = 1, 2 e 3) e p = 90% (1 - probabilidade de perda).

# %%
for i in range(1, 4):
    print(geometric_pmf(i, 0.9))
# Out:
# 0.9
# 0.09
# 0.009

# %% [markdown]
# **Discussões e Resultados**
#
# Observa-se que, quanto maior a sequência de retransmissões, menor é a chance de um pacote precisar ser retransmitido.

# %% [markdown]
# #### Exercício (Slide 39 - Aula 3)

# %% [markdown]
# Considere um sistema computacional com um fluxo de chegadas de 2 jobs por minuto. Modelando esse sistema como Poisson, determine a probabilidade de chegarem, no máximo, três jobs durante um intervalo de 1 minuto
#
# Por se tratar de um evento equiprovável, utiliza-se a variável aleatória de Poisson. Valor de lambda = 2, pelo fluxo de chegada ser 2 jobs por minuto, e a iteração de i = 0, 1, 2 e 3, por se tratar da quantidade máxima de jobs por minuto.

# %%
lmbda = 2
sum = 0
for i in range(4):
    sum += poisson_pmf(lmbda, i)
    print(poisson_pmf(lmbda, i))
print(f"A probabilidade de acontecer, no máximo, 3 jobs por minuto é {round(sum,2)}")
# Out:
# 0.14
# 0.27
# 0.27
# 0.18
# A probabilidade de acontecer, no máximo, 3 jobs por minuto é 0.86

# %% [markdown]
# **Resultados e Discussões**
#
# Conclui-se que a probabilidade do evento ocorrer até x vezes, é a soma das probabilidades inviduais. Também é possível notar na distribuição das probabilidades individuais que as iterações 1 e 2, contém um número igual entre si e maior que as outras.

# %% [markdown]
# ## Variáveis Aleatórias Contínuas

# %% [markdown]
# Implementar as estatísticas para as V.A. contínuas estudadas. Ao escolher uma dessas V.A. para modelar um problema, basta passar os parâmetros que definem o problema.

# %% [markdown]
# #### Uniforme

# %%
model_random_variable('uniform', 2, 5)
# Out:
# Valor Esperado (Média): 3.5
# Variância: 0.75

# %% [markdown]
# **Conclusão**
#
# Para a distribuição uniforme com parâmetros a = 2 e b = 5, as estatísticas calculadas são:
#
# - Valor Esperado (Média): 3,5 <br>
# - Variância: 0,75
#
# Isso indica uma variável aleatória distribuída uniformemente no intervalo [2, 5], onde cada valor dentro desse intervalo é igualmente provável. O valor esperado é o ponto médio do intervalo, e a variância reflete a dispersão da distribuição.

# %% [markdown]
# #### Exponencial

# %%
model_random_variable('exponential', 1)
# Out:
# Valor Esperado (Média): 1.0
# Variância: 1.0

# %% [markdown]
# **Conclusão**
#
# Para a distribuição exponencial com parâmetro λ = 1, as estatísticas calculadas são:
#
# - Valor Esperado (Média): 1 <br>
# - Variância: 1
#
# Isso indica uma distribuição exponencial com média de 1 e variância de 1, que é frequentemente usada para modelar o tempo entre eventos em um processo de Poisson. A função densidade de probabilidade (FDP) diminui rapidamente, mostrando a maior probabilidade de valores menores e a probabilidade decrescente de valores maiores.

# %% [markdown]
# #### Normal

# %%
model_random_variable('normal', 0, 1)
# Out:
# Valor Esperado (Média): 0.000
# Variância: 1.000

# %% [markdown]
# **Conclusão**
#
# Para a distribuição normal com parâmetros μ = 0 e σ = 1, as estatísticas calculadas são:
#
# - Valor Esperado (Média): 0 <br>
# - Variância: 1
#
# Isso indica uma distribuição normal padrão (também conhecida como distribuição Z) com média de 0 e desvio padrão de 1. Esta é uma distribuição simétrica centrada na média, com 68% dos dados dentro de um desvio padrão da média, sendo amplamente utilizada em análises estatísticas e fenômenos naturais.
